# %%
print(bool(false))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e7352c1ea74> in <cell line: 0>()
# ----> 1 print(bool(false))
#       2
#
# NameError: name 'false' is not defined

# %%
print(bool("false"))
return false
# Out:
# True
#   File "<ipython-input-3-e2be3f3e419e>", line 2
#     return false
#     ^
# SyntaxError: 'return' outside function
