# %%
numbers = 0
while True:
  num = int(input("Enter your number"))
  numbers = numbers + num
  if numbers >100:
    break
print(numbers)
# Out:
# Enter your number78
# Enter your number65
# 143

# %%
numbers =0
while True:
  num = int (input("Enter your no:"))
  numbers = numbers +num
  if numbers > 100:
    break
print(numbers)
# Out:
# Enter your no:56
# Enter your no:76
# 132

# %%
numbers = 5
for i in range(5):
  n = int(input("Enter your number:"))
  if i==n:
    continue
  numbers = numbers + n
print(numbers)
# Out:
# Enter your number:1
# Enter your number:2
# Enter your number:3
# Enter your number:4
# Enter your number:5
# 16

# %%
#numbers = 0
for i in range(5):
  n = int(input("Enter your number:"))

  if(i==3):
   continue
print(i+1)
# Out:
# Enter your number:1
# Enter your number:2
# Enter your number:3
# Enter your number:4
# Enter your number:5
# 5

# %%
name ="Mehwish"
print('Hello', name)
print(f"Hello {name}")
# Out:
# Hello Mehwish
# Hello Mehwish

# %%
d

# %%
#import pandas as pd
def total_cost():
  print("Total cost Function started")
  inventory = inputproduct()
  print("Back to total cost function")
  for i in range(2):
  #print("Total cost function ended")
    total_cost = inventory["Price"][i] * inventory["Quantity"][i]
    print("Totalcost",inventory["Product"][i],"is", total_cost)
def inputproduct():
    product = []
    quantity = []
    price = []

    for i in range(3):
        p = input("Enter the product name: ")
        q = int(input("Enter the quantity: "))
        pr = int(input("Enter the price: "))
        product.append(p)
        quantity.append(q)
        price.append(pr)

    inventory = {
        "Product": product,
        "Quantity": quantity,
        "Price": price
    }

    # df = pd.DataFrame(inventory)
    # print(df)

    print(inventory)
    return inventory

# %%
total_cost()
# Out:
# Total cost Function started
# Enter the product name: watch
# Enter the quantity: 3
# Enter the price: 43
# Enter the product name: tv
# Enter the quantity: 45
# Enter the price: 56
# Enter the product name: radio
# Enter the quantity: 56
# Enter the price: 67
# {'Product': ['watch', 'tv', 'radio'], 'Quantity': [3, 45, 56], 'Price': [43, 56, 67]}
# Back to total cost function
# ['watch', 'tv', 'radio']
# watch
# tv
# radio
# [3, 45, 56]
# 3
# 45
# 56
# [43, 56, 67]
# 43
# 56
# 67
